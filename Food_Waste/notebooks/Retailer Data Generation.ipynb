# %%
# %matplotlib inline  

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# Use the retailer loss percentage data taken from USDA:
#   https://www.ers.usda.gov/data-products/food-availability-per-capita-data-system/loss-adjusted-food-availability-documentation/
# https://www.ers.usda.gov/webdocs/publications/47570/8043_tb1927.pdf?v=41056

# %%
# %%writefile retailer_loss.tsv
# Commodity	Food supply (billion lbs)	Losses - Retail (billion lbs)	Losses - Retail (percent)	Losses - Consumer (billion lbs)	Losses - Consumer (percent)	Losses - Total (billion lbs)	Losses - Total (percent)
# Grain products	60.4	7.2	12	11.3	19	18.5	31
# Fresh fruit	37.6	4.4	12	9.5	25	13.9	37
# Processed fruit	26.7	1.6	6	2.9	11	4.5	17
# Fresh vegetables	53.5	5.2	10	12.8	24	18.0	34
# Processed vegetables	30.4	1.8	6	5.3	18	7.1	24
# Fluid milk	53.8	6.5	12	10.5	20	17.0	32
# Other dairy products	29.1	2.8	10	5.7	19	8.5	29
# Meat	31.6	1.4	4	7.2	23	8.6	27
# Poultry	22.0	0.9	4	3.9	18	4.8	22
# Fish and seafood	4.8	0.4	8	1.5	31	1.9	39
# Eggs	9.8	0.7	7	2.1	21	2.8	28
# Tree nuts and peanuts	3.5	0.2	6	0.3	9	0.5	15
# Added sugar and sweeteners	40.8	4.5	11	12.3	30	16.7	41
# Added fats and oils	26.0	5.4	21	4.5	17	9.9	38
# Out:
# Overwriting retailer_loss.tsv

# %%
raw_df = pd.read_csv('./retailer_loss.tsv', sep='\t')

# %%
df = raw_df.copy()
# drop last column, the total column
# df.drop(df.tail(1).index,inplace=True)
df
# Out:
#                      Commodity  Food supply (billion lbs)  \
# 0               Grain products                       60.4
# 1                  Fresh fruit                       37.6
# 2              Processed fruit                       26.7
# 3             Fresh vegetables                       53.5
# 4         Processed vegetables                       30.4
# 5                   Fluid milk                       53.8
# 6         Other dairy products                       29.1
# 7                         Meat                       31.6
# 8                      Poultry                       22.0
# 9             Fish and seafood                        4.8
# 10                        Eggs                        9.8
# 11       Tree nuts and peanuts                        3.5
# 12  Added sugar and sweeteners                       40.8
# 13         Added fats and oils                       26.0
#
#     Losses - Retail (billion lbs)  Losses - Retail (percent)  \
# 0                             7.2                         12
# 1                             4.4                         12
# 2                             1.6                          6
# 3                             5.2                         10
# 4                             1.8                          6
# 5                             6.5                         12
# 6                             2.8                         10
# 7                             1.4                          4
# 8                             0.9                          4
# 9                             0.4                          8
# 10                            0.7                          7
# 11                            0.2                          6
# 12                            4.5                         11
# 13                            5.4                         21
#
#     Losses - Consumer (billion lbs)  Losses - Consumer (percent)  \
# 0                              11.3                           19
# 1                               9.5                           25
# 2                               2.9                           11
# 3                              12.8                           24
# 4                               5.3                           18
# 5                              10.5                           20
# 6                               5.7                           19
# 7                               7.2                           23
# 8                               3.9                           18
# 9                               1.5                           31
# 10                              2.1                           21
# 11                              0.3                            9
# 12                             12.3                           30
# 13                              4.5                           17
#
#     Losses - Total (billion lbs)  Losses - Total (percent)
# 0                           18.5                        31
# 1                           13.9                        37
# 2                            4.5                        17
# 3                           18.0                        34
# 4                            7.1                        24
# 5                           17.0                        32
# 6                            8.5                        29
# 7                            8.6                        27
# 8                            4.8                        22
# 9                            1.9                        39
# 10                           2.8                        28
# 11                           0.5                        15
# 12                          16.7                        41
# 13                           9.9                        38

# %%
df.columns.values
# Out:
# array(['Commodity', 'Food supply (billion lbs)',
#        'Losses - Retail (billion lbs)', 'Losses - Retail (percent)',
#        'Losses - Consumer (billion lbs)', 'Losses - Consumer (percent)',
#        'Losses - Total (billion lbs)', 'Losses - Total (percent)'], dtype=object)

# %%
df_retailer = df[df.columns.values[:4]]
df_retailer.head()
# Out:
#               Commodity  Food supply (billion lbs)  \
# 0        Grain products                       60.4
# 1           Fresh fruit                       37.6
# 2       Processed fruit                       26.7
# 3      Fresh vegetables                       53.5
# 4  Processed vegetables                       30.4
#
#    Losses - Retail (billion lbs)  Losses - Retail (percent)
# 0                            7.2                         12
# 1                            4.4                         12
# 2                            1.6                          6
# 3                            5.2                         10
# 4                            1.8                          6

# %%
total_supply = df_retailer['Food supply (billion lbs)'].sum()
print(total_supply)
df_retailer['supply_normalized_percentage'] = df_retailer['Food supply (billion lbs)'].apply(lambda x: float(x) / total_supply)
df_retailer
# Out:
# 430.0
# /Users/chu/anaconda/envs/py2/lib/python2.7/site-packages/ipykernel/__main__.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()
#                      Commodity  Food supply (billion lbs)  \
# 0               Grain products                       60.4
# 1                  Fresh fruit                       37.6
# 2              Processed fruit                       26.7
# 3             Fresh vegetables                       53.5
# 4         Processed vegetables                       30.4
# 5                   Fluid milk                       53.8
# 6         Other dairy products                       29.1
# 7                         Meat                       31.6
# 8                      Poultry                       22.0
# 9             Fish and seafood                        4.8
# 10                        Eggs                        9.8
# 11       Tree nuts and peanuts                        3.5
# 12  Added sugar and sweeteners                       40.8
# 13         Added fats and oils                       26.0
#
#     Losses - Retail (billion lbs)  Losses - Retail (percent)  \
# 0                             7.2                         12
# 1                             4.4                         12
# 2                             1.6                          6
# 3                             5.2                         10
# 4                             1.8                          6
# 5                             6.5                         12
# 6                             2.8                         10
# 7                             1.4                          4
# 8                             0.9                          4
# 9                             0.4                          8
# 10                            0.7                          7
# 11                            0.2                          6
# 12                            4.5                         11
# 13                            5.4                         21
#
#     supply_normalized_percentage
# 0                       0.140465
# 1                       0.087442
# 2                       0.062093
# 3                       0.124419
# 4                       0.070698
# 5                       0.125116
# 6                       0.067674
# 7                       0.073488
# 8                       0.051163
# 9                       0.011163
# 10                      0.022791
# 11                      0.008140
# 12                      0.094884
# 13                      0.060465

# %%
def get_normalized_loss(r):
    return r['supply_normalized_percentage'] * r['Losses - Retail (percent)'] / 100
df_retailer['retail_normalized_loss'] = df_retailer.apply(get_normalized_loss, axis=1)
# Out:
# /Users/chu/anaconda/envs/py2/lib/python2.7/site-packages/ipykernel/__main__.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()

# %%
df_retailer[['Commodity', 'supply_normalized_percentage', 'retail_normalized_loss']].head(5)
# Out:
#               Commodity  supply_normalized_percentage  retail_normalized_loss
# 0        Grain products                      0.140465                0.016856
# 1           Fresh fruit                      0.087442                0.010493
# 2       Processed fruit                      0.062093                0.003726
# 3      Fresh vegetables                      0.124419                0.012442
# 4  Processed vegetables                      0.070698                0.004242

# %%
169. / 1370
# Out:
# 0.12335766423357664

# %%
df_retailer_normalized = df_retailer[['Commodity', 'supply_normalized_percentage', 'retail_normalized_loss']]

# %%
commodity_idx = np.random.choice(len(df_retailer_normalized),p = df_retailer_normalized['supply_normalized_percentage'].values)
df_retailer_normalized.ix[commodity_idx]
# Out:
# Commodity                             Eggs
# supply_normalized_percentage     0.0227907
# retail_normalized_loss          0.00159535
# Name: 10, dtype: object

# %%
df_retailer_normalized.to_dict(orient='records')
# Out:
# [{'Commodity': 'Grain products',
#   'retail_normalized_loss': 0.010072262367982213,
#   'supply_normalized_percentage': 0.08393551973318511},
#  {'Commodity': 'Fruit',
#   'retail_normalized_loss': 0.008041967759866592,
#   'supply_normalized_percentage': 0.08935519733185103},
#  {'Commodity': 'Fresh fruit',
#   'retail_normalized_loss': 0.006270150083379656,
#   'supply_normalized_percentage': 0.05225125069483047},
#  {'Commodity': 'Processed fruit',
#   'retail_normalized_loss': 0.0022262367982212343,
#   'supply_normalized_percentage': 0.037103946637020574},
#  {'Commodity': 'Vegetables',
#   'retail_normalized_loss': 0.009327404113396333,
#   'supply_normalized_percentage': 0.11659255141745416},
#  {'Commodity': 'Fresh vegetables',
#   'retail_normalized_loss': 0.007434685936631463,
#   'supply_normalized_percentage': 0.07434685936631463},
#  {'Commodity': 'Processed vegetables',
#   'retail_normalized_loss': 0.0025347415230683712,
#   'supply_normalized_percentage': 0.042245692051139525},
#  {'Commodity': 'Dairy products',
#   'retail_normalized_loss': 0.012687604224569207,
#   'supply_normalized_percentage': 0.1153418565869928},
#  {'Commodity': 'Fluid milk',
#   'retail_normalized_loss': 0.008971650917176211,
#   'supply_normalized_percentage': 0.07476375764313509},
#  {'Commodity': 'Other dairy products',
#   'retail_normalized_loss': 0.004043913285158423,
#   'supply_normalized_percentage': 0.04043913285158422},
#  {'Commodity': 'Meat, poultry, and fish',
#   'retail_normalized_loss': 0.00405780989438577,
#   'supply_normalized_percentage': 0.0811561978877154},
#  {'Commodity': 'Meat',
#   'retail_normalized_loss': 0.0017565314063368543,
#   'supply_normalized_percentage': 0.043913285158421356},
#  {'Commodity': 'Poultry',
#   'retail_normalized_loss': 0.0012229016120066704,
#   'supply_normalized_percentage': 0.03057254030016676},
#  {'Commodity': 'Fish and seafood',
#   'retail_normalized_loss': 0.0005336297943301835,
#   'supply_normalized_percentage': 0.0066703724291272935},
#  {'Commodity': 'Eggs',
#   'retail_normalized_loss': 0.000953307392996109,
#   'supply_normalized_percentage': 0.013618677042801558},
#  {'Commodity': 'Tree nuts and peanuts',
#   'retail_normalized_loss': 0.0002918287937743191,
#   'supply_normalized_percentage': 0.004863813229571985},
#  {'Commodity': 'Added sugar and sweeteners',
#   'retail_normalized_loss': 0.006236798221234019,
#   'supply_normalized_percentage': 0.05669816564758199},
#  {'Commodity': 'Added fats and oils',
#   'retail_normalized_loss': 0.0075875486381322965,
#   'supply_normalized_percentage': 0.036131183991106174}]

# %% [markdown]
# ## Now we can finally start simulate some data, for the datasets I am simulating a Gaussian Distribution over the normalized loss

# %%
num_retailer_stores = 2
num_days = 30
restock_period = 7 # change?
sigma_supply = 0.005
sigma_loss = 0.0001

# %%
# personalities? more wasteful, less wasteful, medium wasteful
def getRetailerPersonality(id):
    wasteful_match = {
        0: 0.0001,
        1: 0.0,
        2: -0.0001
    }
    t = id % len(wasteful_match)
    return wasteful_match[t]
getRetailerPersonality(2)
# Out:
# -0.0001

# %%
def generateData():
    data = []
    def generateSupplyGauss(s):
        return np.random.normal(s, sigma_supply, 1)[0]
    def generateLossGauss(s):
        return np.random.normal(s, sigma_loss, 1)[0]
    
    for d in range(num_days):
        for i in range(num_retailer_stores):
            retailer_supply = df_retailer_normalized.copy()
            retailer_supply['retailer_id'] = i
            retailer_supply['day'] = d
            
            # Simulated Supply
            retailer_supply['generated_supply'] = retailer_supply['supply_normalized_percentage'].apply(generateSupplyGauss)
            # Simulated Loss
            retailer_supply['generated_loss'] = retailer_supply['retail_normalized_loss'].apply(generateLossGauss)
            retailer_supply['generated_loss'] = retailer_supply['generated_loss'] + getRetailerPersonality(i)
            
            data += retailer_supply.to_dict(orient='records')
    return pd.DataFrame(data)[['retailer_id','day','Commodity','generated_loss', 'generated_supply']]
data = generateData()
data.groupby('retailer_id').head(20)
# Out:
#     retailer_id  day                   Commodity  generated_loss  \
# 0             0    0              Grain products        0.016945
# 1             0    0                 Fresh fruit        0.010683
# 2             0    0             Processed fruit        0.004018
# 3             0    0            Fresh vegetables        0.012558
# 4             0    0        Processed vegetables        0.004275
# 5             0    0                  Fluid milk        0.015070
# 6             0    0        Other dairy products        0.007032
# 7             0    0                        Meat        0.002936
# 8             0    0                     Poultry        0.001997
# 9             0    0            Fish and seafood        0.000933
# 10            0    0                        Eggs        0.001640
# 11            0    0       Tree nuts and peanuts        0.000587
# 12            0    0  Added sugar and sweeteners        0.010732
# 13            0    0         Added fats and oils        0.012571
# 14            1    0              Grain products        0.016698
# 15            1    0                 Fresh fruit        0.010376
# 16            1    0             Processed fruit        0.003927
# 17            1    0            Fresh vegetables        0.012424
# 18            1    0        Processed vegetables        0.003982
# 19            1    0                  Fluid milk        0.014988
# 20            1    0        Other dairy products        0.006796
# 21            1    0                        Meat        0.002839
# 22            1    0                     Poultry        0.002047
# 23            1    0            Fish and seafood        0.000865
# 24            1    0                        Eggs        0.001496
# 25            1    0       Tree nuts and peanuts        0.000388
# 26            1    0  Added sugar and sweeteners        0.010427
# 27            1    0         Added fats and oils        0.012638
# 28            0    1              Grain products        0.016986
# 29            0    1                 Fresh fruit        0.010476
# 30            0    1             Processed fruit        0.003839
# 31            0    1            Fresh vegetables        0.012774
# 32            0    1        Processed vegetables        0.004307
# 33            0    1                  Fluid milk        0.015173
# 42            1    1              Grain products        0.016808
# 43            1    1                 Fresh fruit        0.010457
# 44            1    1             Processed fruit        0.003718
# 45            1    1            Fresh vegetables        0.012486
# 46            1    1        Processed vegetables        0.004284
# 47            1    1                  Fluid milk        0.015117
#
#     generated_supply
# 0           0.137111
# 1           0.089904
# 2           0.059931
# 3           0.123725
# 4           0.076965
# 5           0.125252
# 6           0.068632
# 7           0.073081
# 8           0.055707
# 9           0.014694
# 10          0.026179
# 11          0.010321
# 12          0.084441
# 13          0.064561
# 14          0.134214
# 15          0.090099
# 16          0.065290
# 17          0.123076
# 18          0.068794
# 19          0.122031
# 20          0.066958
# 21          0.077469
# 22          0.056777
# 23          0.011350
# 24          0.022188
# 25          0.005970
# 26          0.092154
# 27          0.054607
# 28          0.144162
# 29          0.090097
# 30          0.059935
# 31          0.127411
# 32          0.076075
# 33          0.118894
# 42          0.140858
# 43          0.089145
# 44          0.065194
# 45          0.120127
# 46          0.071537
# 47          0.128754

# %% [markdown]
# ## Integrate stocking patterns

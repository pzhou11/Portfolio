# %%
import pandas as pd
import json
from collections import defaultdict
import numpy as np
import simplejson

# %%
df = pd.read_csv('test1.csv')

# %%
yrs = df['yr'].unique()

# %%
df["MTH"] =  pd.Categorical(df['MTH'], ['Jan', 'Feb', 'Mar','Apr', 'May', 'Jun','Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'])

# %%
table = pd.pivot_table(df, index=['yr', 'ITEM_CLASS'], columns=['MTH'], aggfunc=np.sum)

# %%
table
# Out:
#                           POPN_WASTED_DOLLARS                                \
# MTH                                       Jan   Feb   Mar   Apr   May   Jun
# yr   ITEM_CLASS
# 2016 DAIRY                                NaN   NaN   NaN  1.32  0.81  1.15
#      FISH                                 NaN   NaN   NaN  0.92  0.77  0.92
#      FOWL                                 NaN   NaN   NaN  2.21  2.02  1.49
#      FRESH FRUIT                          NaN   NaN   NaN  1.29  1.29  1.79
#      FRESH VEGETABLES                     NaN   NaN   NaN  1.43  1.03  1.00
#      MEAT                                 NaN   NaN   NaN  2.11  1.86  2.40
#      MILK                                 NaN   NaN   NaN  2.73  0.91  1.42
#      PROCESSED FRUIT                      NaN   NaN   NaN  0.65  1.03  0.62
#      PROCESSED VEGETABLES                 NaN   NaN   NaN  2.54  2.73  1.99
# 2017 DAIRY                               1.28  1.14  1.47  1.21  1.21  1.28
#      FISH                                1.41  1.09  0.97  1.07  1.11  1.16
#      FOWL                                1.77  2.00  1.73  1.73  1.36  1.49
#      FRESH FRUIT                         1.03  0.92  0.98  1.04  1.61  1.66
#      FRESH VEGETABLES                    1.23  1.24  1.28  1.49  1.23  1.40
#      MEAT                                2.83  2.77  2.79  2.93  2.53  2.76
#      MILK                                1.54  1.24  1.91  2.59  1.56  2.06
#      PROCESSED FRUIT                     0.86  0.93  0.68  0.86  0.79  0.74
#      PROCESSED VEGETABLES                0.99  1.13  0.98  1.48  1.09  1.10
# 2018 DAIRY                               1.21  1.22  1.07   NaN   NaN   NaN
#      FISH                                1.25  1.16  1.24   NaN   NaN   NaN
#      FOWL                                2.14  1.77  1.69   NaN   NaN   NaN
#      FRESH FRUIT                         1.16  0.66  1.19   NaN   NaN   NaN
#      FRESH VEGETABLES                    1.28  1.21  1.31   NaN   NaN   NaN
#      MEAT                                2.63  2.54  2.48   NaN   NaN   NaN
#      MILK                                1.68  2.18  1.45   NaN   NaN   NaN
#      PROCESSED FRUIT                     0.96  0.77  0.77   NaN   NaN   NaN
#      PROCESSED VEGETABLES                1.38  1.48  1.01   NaN   NaN   NaN
#
#                                                    ...   YOUR_WASTED_DOLLAR  \
# MTH                         Jul   Aug   Sep   Oct  ...                  Mar
# yr   ITEM_CLASS                                    ...
# 2016 DAIRY                 1.18  1.22  1.08  1.09  ...                  NaN
#      FISH                  0.83  0.85  1.01  0.94  ...                  NaN
#      FOWL                  2.70  2.03  1.91  1.72  ...                  NaN
#      FRESH FRUIT           2.48  1.46  2.11  0.99  ...                  NaN
#      FRESH VEGETABLES      1.50  1.11  1.08  0.98  ...                  NaN
#      MEAT                  2.99  3.56  3.36  3.24  ...                  NaN
#      MILK                  2.14  1.49  1.51  0.85  ...                  NaN
#      PROCESSED FRUIT       1.08  0.65  0.62  0.61  ...                  NaN
#      PROCESSED VEGETABLES  1.31  1.27  0.82  1.35  ...                  NaN
# 2017 DAIRY                 1.14  1.20  1.50  1.32  ...                13.82
#      FISH                  1.14  1.06  1.21  1.13  ...                 4.78
#      FOWL                  1.62  1.98  1.61  2.35  ...                 2.71
#      FRESH FRUIT           1.59  1.44  0.97  0.81  ...                 1.16
#      FRESH VEGETABLES      1.15  1.12  1.26  1.26  ...                 3.84
#      MEAT                  2.88  2.99  2.89  2.48  ...                28.22
#      MILK                  1.82  2.22  2.38  1.50  ...                 0.00
#      PROCESSED FRUIT       0.91  0.81  0.62  0.89  ...                 0.00
#      PROCESSED VEGETABLES  0.93  2.16  0.81  0.79  ...                 0.46
# 2018 DAIRY                  NaN   NaN   NaN   NaN  ...                 0.82
#      FISH                   NaN   NaN   NaN   NaN  ...                 0.02
#      FOWL                   NaN   NaN   NaN   NaN  ...                 1.11
#      FRESH FRUIT            NaN   NaN   NaN   NaN  ...                 0.00
#      FRESH VEGETABLES       NaN   NaN   NaN   NaN  ...                 0.00
#      MEAT                   NaN   NaN   NaN   NaN  ...                 3.79
#      MILK                   NaN   NaN   NaN   NaN  ...                 0.00
#      PROCESSED FRUIT        NaN   NaN   NaN   NaN  ...                 0.01
#      PROCESSED VEGETABLES   NaN   NaN   NaN   NaN  ...                 0.00
#
#                                                                             \
# MTH                          Apr    May    Jun    Jul    Aug    Sep    Oct
# yr   ITEM_CLASS
# 2016 DAIRY                  9.20   7.81  20.95   8.64   1.08   0.00   0.11
#      FISH                   0.00   0.42   0.49   3.17   0.00   0.00   0.00
#      FOWL                   0.00   5.14   0.00   0.75   0.00   0.00   0.92
#      FRESH FRUIT            0.42   0.00   0.87   2.69   0.17   0.00   0.00
#      FRESH VEGETABLES       0.12   6.98   0.33   2.62   0.73   0.00   5.71
#      MEAT                  25.01  16.13   0.53   3.85   0.00   0.00   0.64
#      MILK                   1.04   0.00   0.04   7.56   0.25   0.00   0.00
#      PROCESSED FRUIT        0.03   9.10   3.34   0.72   4.98   0.00   0.00
#      PROCESSED VEGETABLES  26.19  11.76   0.09   5.61   0.97   0.00   0.21
# 2017 DAIRY                  4.83   3.85   8.94  22.62  31.24  11.63  15.27
#      FISH                   1.48   0.09   0.09   0.00  18.34   0.42   0.26
#      FOWL                   2.96   0.00   0.26   0.00   0.00   4.90   8.31
#      FRESH FRUIT            1.17   0.22   0.00   0.36   0.67   0.28   0.00
#      FRESH VEGETABLES       3.66   2.81   1.24   0.19   0.00   0.72   0.01
#      MEAT                   7.25   5.25   9.57   3.70   2.22   7.75  58.19
#      MILK                   0.00   0.00   0.85   0.00   0.65   0.00   0.09
#      PROCESSED FRUIT        0.74   1.72   2.06   0.82  40.71   1.42   0.00
#      PROCESSED VEGETABLES   1.80   1.00   2.56   0.00  10.12   3.17   5.91
# 2018 DAIRY                   NaN    NaN    NaN    NaN    NaN    NaN    NaN
#      FISH                    NaN    NaN    NaN    NaN    NaN    NaN    NaN
#      FOWL                    NaN    NaN    NaN    NaN    NaN    NaN    NaN
#      FRESH FRUIT             NaN    NaN    NaN    NaN    NaN    NaN    NaN
#      FRESH VEGETABLES        NaN    NaN    NaN    NaN    NaN    NaN    NaN
#      MEAT                    NaN    NaN    NaN    NaN    NaN    NaN    NaN
#      MILK                    NaN    NaN    NaN    NaN    NaN    NaN    NaN
#      PROCESSED FRUIT         NaN    NaN    NaN    NaN    NaN    NaN    NaN
#      PROCESSED VEGETABLES    NaN    NaN    NaN    NaN    NaN    NaN    NaN
#
#
# MTH                          Nov    Dec
# yr   ITEM_CLASS
# 2016 DAIRY                 13.24   1.39
#      FISH                   0.99   6.28
#      FOWL                   0.00   7.54
#      FRESH FRUIT            0.00   0.00
#      FRESH VEGETABLES       7.16   3.40
#      MEAT                   4.51   1.42
#      MILK                   2.09  26.06
#      PROCESSED FRUIT        0.00   7.60
#      PROCESSED VEGETABLES   0.28   0.39
# 2017 DAIRY                  2.48   3.94
#      FISH                   0.20   0.36
#      FOWL                   0.03   4.52
#      FRESH FRUIT            0.00   1.22
#      FRESH VEGETABLES       0.00   9.49
#      MEAT                   1.50  12.40
#      MILK                   0.00   0.00
#      PROCESSED FRUIT        0.00   0.00
#      PROCESSED VEGETABLES   0.72   0.85
# 2018 DAIRY                   NaN    NaN
#      FISH                    NaN    NaN
#      FOWL                    NaN    NaN
#      FRESH FRUIT             NaN    NaN
#      FRESH VEGETABLES        NaN    NaN
#      MEAT                    NaN    NaN
#      MILK                    NaN    NaN
#      PROCESSED FRUIT         NaN    NaN
#      PROCESSED VEGETABLES    NaN    NaN
#
# [27 rows x 24 columns]

# %%
table.to_json('file.json',orient='split')

# %%
chk2 = json.load(open('file.json'))

# %%
chk2
# Out:
# {u'columns': [[u'POPN_WASTED_DOLLARS', u'Jan'],
#   [u'POPN_WASTED_DOLLARS', u'Feb'],
#   [u'POPN_WASTED_DOLLARS', u'Mar'],
#   [u'POPN_WASTED_DOLLARS', u'Apr'],
#   [u'POPN_WASTED_DOLLARS', u'May'],
#   [u'POPN_WASTED_DOLLARS', u'Jun'],
#   [u'POPN_WASTED_DOLLARS', u'Jul'],
#   [u'POPN_WASTED_DOLLARS', u'Aug'],
#   [u'POPN_WASTED_DOLLARS', u'Sep'],
#   [u'POPN_WASTED_DOLLARS', u'Oct'],
#   [u'POPN_WASTED_DOLLARS', u'Nov'],
#   [u'POPN_WASTED_DOLLARS', u'Dec'],
#   [u'YOUR_WASTED_DOLLAR', u'Jan'],
#   [u'YOUR_WASTED_DOLLAR', u'Feb'],
#   [u'YOUR_WASTED_DOLLAR', u'Mar'],
#   [u'YOUR_WASTED_DOLLAR', u'Apr'],
#   [u'YOUR_WASTED_DOLLAR', u'May'],
#   [u'YOUR_WASTED_DOLLAR', u'Jun'],
#   [u'YOUR_WASTED_DOLLAR', u'Jul'],
#   [u'YOUR_WASTED_DOLLAR', u'Aug'],
#   [u'YOUR_WASTED_DOLLAR', u'Sep'],
#   [u'YOUR_WASTED_DOLLAR', u'Oct'],
#   [u'YOUR_WASTED_DOLLAR', u'Nov'],
#   [u'YOUR_WASTED_DOLLAR', u'Dec']],
#  u'data': [[None,
#    None,
#    None,
#    1.32,
#    0.81,
#    1.15,
#    1.18,
#    1.22,
#    1.08,
#    1.09,
#    1.09,
#    1.26,
#    None,
#    None,
#    None,
#    9.2,
#    7.81,
#    20.95,
#    8.64,
#    1.08,
#    0.0,
#    0.11,
#    13.24,
#    1.39],
#   [None,
#    None,
#    None,
#    0.92,
#    0.77,
#    0.92,
#    0.83,
#    0.85,
#    1.01,
#    0.94,
#    1.1,
#    1.12,
#    None,
#    None,
#    None,
#    0.0,
#    0.42,
#    0.49,
#    3.17,
#    0.0,
#    0.0,
#    0.0,
#    0.99,
#    6.28],
#   [None,
#    None,
#    None,
#    2.21,
#    2.02,
#    1.49,
#    2.7,
#    2.03,
#    1.91,
#    1.72,
#    1.53,
#    1.52,
#    None,
#    None,
#    None,
#    0.0,
#    5.14,
#    0.0,
#    0.75,
#    0.0,
#    0.0,
#    0.92,
#    0.0,
#    7.54],
#   [None,
#    None,
#    None,
#    1.29,
#    1.29,
#    1.79,
#    2.48,
#    1.46,
#    2.11,
#    0.99,
#    1.14,
#    1.11,
#    None,
#    None,
#    None,
#    0.42,
#    0.0,
#    0.87,
#    2.69,
#    0.17,
#    0.0,
#    0.0,
#    0.0,
#    0.0],
#   [None,
#    None,
#    None,
#    1.43,
#    1.03,
#    1.0,
#    1.5,
#    1.11,
#    1.08,
#    0.98,
#    1.45,
#    1.37,
#    None,
#    None,
#    None,
#    0.12,
#    6.98,
#    0.33,
#    2.62,
#    0.73,
#    0.0,
#    5.71,
#    7.16,
#    3.4],
#   [None,
#    None,
#    None,
#    2.11,
#    1.86,
#    2.4,
#    2.99,
#    3.56,
#    3.36,
#    3.24,
#    3.11,
#    2.71,
#    None,
#    None,
#    None,
#    25.01,
#    16.13,
#    0.53,
#    3.85,
#    0.0,
#    0.0,
#    0.64,
#    4.51,
#    1.42],
#   [None,
#    None,
#    None,
#    2.73,
#    0.91,
#    1.42,
#    2.14,
#    1.49,
#    1.51,
#    0.85,
#    2.14,
#    2.47,
#    None,
#    None,
#    None,
#    1.04,
#    0.0,
#    0.04,
#    7.56,
#    0.25,
#    0.0,
#    0.0,
#    2.09,
#    26.06],
#   [None,
#    None,
#    None,
#    0.65,
#    1.03,
#    0.62,
#    1.08,
#    0.65,
#    0.62,
#    0.61,
#    0.66,
#    0.66,
#    None,
#    None,
#    None,
#    0.03,
#    9.1,
#    3.34,
#    0.72,
#    4.98,
#    0.0,
#    0.0,
#    0.0,
#    7.6],
#   [None,
#    None,
#    None,
#    2.54,
#    2.73,
#    1.99,
#    1.31,
#    1.27,
#    0.82,
#    1.35,
#    0.96,
#    1.71,
#    None,
#    None,
#    None,
#    26.19,
#    11.76,
#    0.09,
#    5.61,
#    0.97,
#    0.0,
#    0.21,
#    0.28,
#    0.39],
#   [1.28,
#    1.14,
#    1.47,
#    1.21,
#    1.21,
#    1.28,
#    1.14,
#    1.2,
#    1.5,
#    1.32,
#    1.13,
#    1.3,
#    4.38,
#    8.17,
#    13.82,
#    4.83,
#    3.85,
#    8.94,
#    22.62,
#    31.24,
#    11.63,
#    15.27,
#    2.48,
#    3.94],
#   [1.41,
#    1.09,
#    0.97,
#    1.07,
#    1.11,
#    1.16,
#    1.14,
#    1.06,
#    1.21,
#    1.13,
#    1.06,
#    1.24,
#    0.59,
#    2.21,
#    4.78,
#    1.48,
#    0.09,
#    0.09,
#    0.0,
#    18.34,
#    0.42,
#    0.26,
#    0.2,
#    0.36],
#   [1.77,
#    2.0,
#    1.73,
#    1.73,
#    1.36,
#    1.49,
#    1.62,
#    1.98,
#    1.61,
#    2.35,
#    2.12,
#    2.07,
#    7.41,
#    6.27,
#    2.71,
#    2.96,
#    0.0,
#    0.26,
#    0.0,
#    0.0,
#    4.9,
#    8.31,
#    0.03,
#    4.52],
#   [1.03,
#    0.92,
#    0.98,
#    1.04,
#    1.61,
#    1.66,
#    1.59,
#    1.44,
#    0.97,
#    0.81,
#    0.88,
#    0.94,
#    0.15,
#    0.0,
#    1.16,
#    1.17,
#    0.22,
#    0.0,
#    0.36,
#    0.67,
#    0.28,
#    0.0,
#    0.0,
#    1.22],
#   [1.23,
#    1.24,
#    1.28,
#    1.49,
#    1.23,
#    1.4,
#    1.15,
#    1.12,
#    1.26,
#    1.26,
#    1.21,
#    1.3,
#    0.67,
#    0.6,
#    3.84,
#    3.66,
#    2.81,
#    1.24,
#    0.19,
#    0.0,
#    0.72,
#    0.01,
#    0.0,
#    9.49],
#   [2.83,
#    2.77,
#    2.79,
#    2.93,
#    2.53,
#    2.76,
#    2.88,
#    2.99,
#    2.89,
#    2.48,
#    2.49,
#    2.58,
#    1.16,
#    11.44,
#    28.22,
#    7.25,
#    5.25,
#    9.57,
#    3.7,
#    2.22,
#    7.75,
#    58.19,
#    1.5,
#    12.4],
#   [1.54,
#    1.24,
#    1.91,
#    2.59,
#    1.56,
#    2.06,
#    1.82,
#    2.22,
#    2.38,
#    1.5,
#    0.97,
#    1.64,
#    0.0,
#    2.3,
#    0.0,
#    0.0,
#    0.0,
#    0.85,
#    0.0,
#    0.65,
#    0.0,
#    0.09,
#    0.0,
#    0.0],
#   [0.86,
#    0.93,
#    0.68,
#    0.86,
#    0.79,
#    0.74,
#    0.91,
#    0.81,
#    0.62,
#    0.89,
#    0.91,
#    0.95,
#    0.0,
#    0.53,
#    0.0,
#    0.74,
#    1.72,
#    2.06,
#    0.82,
#    40.71,
#    1.42,
#    0.0,
#    0.0,
#    0.0],
#   [0.99,
#    1.13,
#    0.98,
#    1.48,
#    1.09,
#    1.1,
#    0.93,
#    2.16,
#    0.81,
#    0.79,
#    0.76,
#    1.28,
#    4.3,
#    3.76,
#    0.46,
#    1.8,
#    1.0,
#    2.56,
#    0.0,
#    10.12,
#    3.17,
#    5.91,
#    0.72,
#    0.85],
#   [1.21,
#    1.22,
#    1.07,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    2.64,
#    7.3,
#    0.82,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None],
#   [1.25,
#    1.16,
#    1.24,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    0.26,
#    0.0,
#    0.02,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None],
#   [2.14,
#    1.77,
#    1.69,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    0.0,
#    1.31,
#    1.11,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None],
#   [1.16,
#    0.66,
#    1.19,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    0.0,
#    0.0,
#    0.0,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None],
#   [1.28,
#    1.21,
#    1.31,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    0.0,
#    0.0,
#    0.0,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None],
#   [2.63,
#    2.54,
#    2.48,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    0.34,
#    3.09,
#    3.79,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None],
#   [1.68,
#    2.18,
#    1.45,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    0.0,
#    0.0,
#    0.0,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None],
#   [0.96,
#    0.77,
#    0.77,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    0.0,
#    0.0,
#    0.01,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None],
#   [1.38,
#    1.48,
#    1.01,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    0.0,
#    0.25,
#    0.0,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None]],
#  u'index': [[2016, u'DAIRY'],
#   [2016, u'FISH'],
#   [2016, u'FOWL'],
#   [2016, u'FRESH FRUIT'],
#   [2016, u'FRESH VEGETABLES'],
#   [2016, u'MEAT'],
#   [2016, u'MILK'],
#   [2016, u'PROCESSED FRUIT'],
#   [2016, u'PROCESSED VEGETABLES'],
#   [2017, u'DAIRY'],
#   [2017, u'FISH'],
#   [2017, u'FOWL'],
#   [2017, u'FRESH FRUIT'],
#   [2017, u'FRESH VEGETABLES'],
#   [2017, u'MEAT'],
#   [2017, u'MILK'],
#   [2017, u'PROCESSED FRUIT'],
#   [2017, u'PROCESSED VEGETABLES'],
#   [2018, u'DAIRY'],
#   [2018, u'FISH'],
#   [2018, u'FOWL'],
#   [2018, u'FRESH FRUIT'],
#   [2018, u'FRESH VEGETABLES'],
#   [2018, u'MEAT'],
#   [2018, u'MILK'],
#   [2018, u'PROCESSED FRUIT'],
#   [2018, u'PROCESSED VEGETABLES']]}

# %%
from orderedset import OrderedSet
yrs = OrderedSet([i[0] for i in chk2['index']])
items = OrderedSet([i[1] for i in chk2['index']])
metrics = OrderedSet([i[0] for i in chk2['columns']])
mths = ['Jan', 'Feb', 'Mar','Apr', 'May', 'Jun','Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']

print [chk2['data'][i] for i in np.where(np.array(chk2['index']) == 'DAIRY')[0]]
##yr-prod-combo = []
#for i in yrs:
#    for j in items:
#        yr-prod-combo.append(str(i) + "-" +  j)
        
        
#print len(combo), len(chk2['data'])
# Out:
# [[None, None, None, 1.32, 0.81, 1.15, 1.18, 1.22, 1.08, 1.09, 1.09, 1.26, None, None, None, 9.2, 7.81, 20.95, 8.64, 1.08, 0.0, 0.11, 13.24, 1.39], [1.28, 1.14, 1.47, 1.21, 1.21, 1.28, 1.14, 1.2, 1.5, 1.32, 1.13, 1.3, 4.38, 8.17, 13.82, 4.83, 3.85, 8.94, 22.62, 31.24, 11.63, 15.27, 2.48, 3.94], [1.21, 1.22, 1.07, None, None, None, None, None, None, None, None, None, 2.64, 7.3, 0.82, None, None, None, None, None, None, None, None, None]]

# %%
indices = chk2['index']
datum = chk2['data']
cols = chk2['columns']
cuts = [len(datum[0])/(len(metrics) - metrics.index(i)) for i in metrics]
print cuts

productDict = {k:dict() for k in items}


for i in yrs:
    for j in productDict.values():
        j[i] = []

        
for i in metrics:
    for j in yrs:
        for k in items:
            dataitems = [chk2['data'][z] for z in np.where(np.array(chk2['index']) == k)[0]]
            data_for_metric = dataitems[yrs.index(j)][cuts[metrics.index(i)]-12:cuts[metrics.index(i)]]
            productDict[k][j].append({"name":i, "data":[[mths[f],data_for_metric[f]] for f in range(len(data_for_metric))]})

print productDict['DAIRY'][2016]
# Out:
# [12, 24]
# [{'data': [['Jan', None], ['Feb', None], ['Mar', None], ['Apr', 1.32], ['May', 0.81], ['Jun', 1.15], ['Jul', 1.18], ['Aug', 1.22], ['Sep', 1.08], ['Oct', 1.09], ['Nov', 1.09], ['Dec', 1.26]], 'name': u'POPN_WASTED_DOLLARS'}, {'data': [['Jan', None], ['Feb', None], ['Mar', None], ['Apr', 9.2], ['May', 7.81], ['Jun', 20.95], ['Jul', 8.64], ['Aug', 1.08], ['Sep', 0.0], ['Oct', 0.11], ['Nov', 13.24], ['Dec', 1.39]], 'name': u'YOUR_WASTED_DOLLAR'}]

# %%
#seriesList = []
seriesDict = {k:[] for k in items}

for i in metrics:
    for j in items:
        dataitems = [chk2['data'][z] for z in np.where(np.array(chk2['index']) == j)[0]]
        #print dataitems
        seriesDict[j].append({"name" : i, "data": [{"name": l, "drilldown":True, "y": round(sum([ f for f in dataitems[yrs.index(l)][cuts[metrics.index(i)]-12:cuts[metrics.index(i)]] if f is not None]),2)} for l in yrs]})

seriesDict
# Out:
# {u'DAIRY': [{'data': [{'drilldown': True, 'name': 2016, 'y': 10.2},
#     {'drilldown': True, 'name': 2017, 'y': 15.18},
#     {'drilldown': True, 'name': 2018, 'y': 3.5}],
#    'name': u'POPN_WASTED_DOLLARS'},
#   {'data': [{'drilldown': True, 'name': 2016, 'y': 62.42},
#     {'drilldown': True, 'name': 2017, 'y': 131.17},
#     {'drilldown': True, 'name': 2018, 'y': 10.76}],
#    'name': u'YOUR_WASTED_DOLLAR'}],
#  u'FISH': [{'data': [{'drilldown': True, 'name': 2016, 'y': 8.46},
#     {'drilldown': True, 'name': 2017, 'y': 13.65},
#     {'drilldown': True, 'name': 2018, 'y': 3.65}],
#    'name': u'POPN_WASTED_DOLLARS'},
#   {'data': [{'drilldown': True, 'name': 2016, 'y': 11.35},
#     {'drilldown': True, 'name': 2017, 'y': 28.82},
#     {'drilldown': True, 'name': 2018, 'y': 0.28}],
#    'name': u'YOUR_WASTED_DOLLAR'}],
#  u'FOWL': [{'data': [{'drilldown': True, 'name': 2016, 'y': 17.13},
#     {'drilldown': True, 'name': 2017, 'y': 21.83},
#     {'drilldown': True, 'name': 2018, 'y': 5.6}],
#    'name': u'POPN_WASTED_DOLLARS'},
#   {'data': [{'drilldown': True, 'name': 2016, 'y': 14.35},
#     {'drilldown': True, 'name': 2017, 'y': 37.37},
#     {'drilldown': True, 'name': 2018, 'y': 2.42}],
#    'name': u'YOUR_WASTED_DOLLAR'}],
#  u'FRESH FRUIT': [{'data': [{'drilldown': True, 'name': 2016, 'y': 13.66},
#     {'drilldown': True, 'name': 2017, 'y': 13.87},
#     {'drilldown': True, 'name': 2018, 'y': 3.01}],
#    'name': u'POPN_WASTED_DOLLARS'},
#   {'data': [{'drilldown': True, 'name': 2016, 'y': 4.15},
#     {'drilldown': True, 'name': 2017, 'y': 5.23},
#     {'drilldown': True, 'name': 2018, 'y': 0.0}],
#    'name': u'YOUR_WASTED_DOLLAR'}],
#  u'FRESH VEGETABLES': [{'data': [{'drilldown': True, 'name': 2016, 'y': 10.95},
#     {'drilldown': True, 'name': 2017, 'y': 15.17},
#     {'drilldown': True, 'name': 2018, 'y': 3.8}],
#    'name': u'POPN_WASTED_DOLLARS'},
#   {'data': [{'drilldown': True, 'name': 2016, 'y': 27.05},
#     {'drilldown': True, 'name': 2017, 'y': 23.23},
#     {'drilldown': True, 'name': 2018, 'y': 0.0}],
#    'name': u'YOUR_WASTED_DOLLAR'}],
#  u'MEAT': [{'data': [{'drilldown': True, 'name': 2016, 'y': 25.34},
#     {'drilldown': True, 'name': 2017, 'y': 32.92},
#     {'drilldown': True, 'name': 2018, 'y': 7.65}],
#    'name': u'POPN_WASTED_DOLLARS'},
#   {'data': [{'drilldown': True, 'name': 2016, 'y': 52.09},
#     {'drilldown': True, 'name': 2017, 'y': 148.65},
#     {'drilldown': True, 'name': 2018, 'y': 7.22}],
#    'name': u'YOUR_WASTED_DOLLAR'}],
#  u'MILK': [{'data': [{'drilldown': True, 'name': 2016, 'y': 15.66},
#     {'drilldown': True, 'name': 2017, 'y': 21.43},
#     {'drilldown': True, 'name': 2018, 'y': 5.31}],
#    'name': u'POPN_WASTED_DOLLARS'},
#   {'data': [{'drilldown': True, 'name': 2016, 'y': 37.04},
#     {'drilldown': True, 'name': 2017, 'y': 3.89},
#     {'drilldown': True, 'name': 2018, 'y': 0.0}],
#    'name': u'YOUR_WASTED_DOLLAR'}],
#  u'PROCESSED FRUIT': [{'data': [{'drilldown': True, 'name': 2016, 'y': 6.58},
#     {'drilldown': True, 'name': 2017, 'y': 9.95},
#     {'drilldown': True, 'name': 2018, 'y': 2.5}],
#    'name': u'POPN_WASTED_DOLLARS'},
#   {'data': [{'drilldown': True, 'name': 2016, 'y': 25.77},
#     {'drilldown': True, 'name': 2017, 'y': 48.0},
#     {'drilldown': True, 'name': 2018, 'y': 0.01}],
#    'name': u'YOUR_WASTED_DOLLAR'}],
#  u'PROCESSED VEGETABLES': [{'data': [{'drilldown': True,
#      'name': 2016,
#      'y': 14.68},
#     {'drilldown': True, 'name': 2017, 'y': 13.5},
#     {'drilldown': True, 'name': 2018, 'y': 3.87}],
#    'name': u'POPN_WASTED_DOLLARS'},
#   {'data': [{'drilldown': True, 'name': 2016, 'y': 45.5},
#     {'drilldown': True, 'name': 2017, 'y': 34.65},
#     {'drilldown': True, 'name': 2018, 'y': 0.25}],
#    'name': u'YOUR_WASTED_DOLLAR'}]}

# %%
f1 = open('data.json', 'w')
f2 = open('axis.json', 'w')
simplejson.dump(finalDict, f1)
simplejson.dump(column_order, f2)

# %%
for  item in items:
    f1n =  'data' + str(item) + '.json'
    f2n = 'series' + str(item) + '.json'
    f1 = open(f1n, 'w')
    f2 = open(f2n, 'w')
    simplejson.dump(productDict[item], f1)
    simplejson.dump(seriesDict[item], f1)
